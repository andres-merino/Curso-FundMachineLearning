# %% [markdown]
# <a href="https://colab.research.google.com/github/andres-merino/Curso-FundMachineLearning/blob/main/4-Ejercicios/08-Optimizacion-Hiperparametros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table style="border: none; border-collapse: collapse;">
#     <tr>
#         <td style="width: 20%; vertical-align: middle; padding-right: 10px;">
#             <img src="https://i0.wp.com/see-ec.org/wordpress/wp-content/uploads/2023/01/LOGO-SEE-texto-blanco-3.png?w=1356&ssl=1" width="200">
#         </td>
#         <td style="width: 2px; text-align: center;">
#             <font color="#008dc3" size="7">|</font><br>
#             <font color="#008dc3" size="7">|</font>
#         </td>
#         <td>
#             <p style="font-variant: small-caps;"><font color="#008dc3" size="5">
#                 <b>Sociedad Ecuatoriana de Estadística</b>
#             </font> </p>
#             <p style="font-variant: small-caps;"><font color="#008dc3" size="4">
#                 Aprendizaje Automático Inicial &bull; Optmización de Hiperparámetros
#             </font></p>
#             <p style="font-style: oblique;"><font color="#008dc3" size="3">
#                 Andrés Merino &bull; 2025-04
#             </font></p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ---
# ## <font color='008dc3'> Introducción </font>
#
# A lo largo de este taller, aplicaremos optimización de hiperparámetros en un modelo que elijas.

# %% [markdown]
# Los paquetes necesarios son:

# %%
# Paquetes necesarios

# %% [markdown]
# ---
# ## <font color='008dc3'> Clasificación </font>

# %% [markdown]
# ### <font color='008dc3'> Preprocesamiento de datos </font>

# %% [markdown]
# Primero necesitas el conjunto de datos. Los datos a utilzar son los seleccionados en la clase anterior.
#
# <div style="background-color: #edf1f8; border-color: #008dc3; border-left: 5px solid #008dc3; padding: 0.5em;">
# <strong>Ejercicio:</strong><br>
#     Carga el conjunto de datos y procésalos:
# <ul>
#   <li>Muestra algunos datos.</li>
#   <li>Muestra una descripción de los datos.</li>
#   <li>Escala los datos si es necesario.</li>
# </ul>
# </div>

# %% [markdown]
# ### <font color='008dc3'> Modelo </font>

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #008dc3; border-left: 5px solid #008dc3; padding: 0.5em;">
# <strong>Ejercicio:</strong><br>
#     Selecciona el mejor modelo de las clases anteriores.
# <ul>
#   <li>Muestra los hiperparámetros del modelo.</li>
#   <li>Consulta qué significan al menos 4 hiperparámetros.</li>
#   <li>Selecciona los hiperparámetros que deseas optimizar, al menos 3.</li>
# </ul>
# </div>

# %% [markdown]
# ### <font color='008dc3'> Optimización por GridSearch </font>

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #008dc3; border-left: 5px solid #008dc3; padding: 0.5em;">
# <strong>Ejercicio:</strong><br>
#     Aplica GridSearch para optimizar los hiperparámetros del modelo.
# <ul>
#   <li>Para cada hiperparámetro, selecciona al menos 3 valores, si es posible.</li>
#   <li>Utiliza al menos 5 validaciones cruzadas.</li>
#   <li>Muestra los parámetros óptimos y su score.</li>
# </ul>
# </div>

# %% [markdown]
# ### <font color='008dc3'> Optimización por RandomSearch </font>

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #008dc3; border-left: 5px solid #008dc3; padding: 0.5em;">
# <strong>Ejercicio:</strong><br>
#     Aplica RandomSearch para optimizar los hiperparámetros del modelo.
# <ul>
#   <li>Para cada hiperparámetro, selecciona al menos 5 valores, si es posible.</li>
#   <li>Utiliza al menos 5 validaciones cruzadas.</li>
#   <li>Usa RandomSearchCV con 25 iteraciones.</li>
#   <li>Muestra los parámetros óptimos y su score.</li>
# </ul>
# </div>

# %% [markdown]
# ### <font color='008dc3'> Guardado de modelo </font>

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #008dc3; border-left: 5px solid #008dc3; padding: 0.5em;">
# <strong>Ejercicio:</strong><br>
#   Con los parámetros óptimos que mejor resultado dieron, reentrena el modelo, muestra su score y guárdalo.
# </div>

# %% [markdown]
# ### <font color='008dc3'> Publicación </font>

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #008dc3; border-left: 5px solid #008dc3; padding: 0.5em;">
# <strong>Ejercicio:</strong><br>
#   Coloca el este cuaderno y el modelo en tu repositorio de GitHub. Agrega una licencia MIT y un README.md donde se explique el contenido del repositorio, los datos utilizados y los resultados obtenidos.
# </div>
