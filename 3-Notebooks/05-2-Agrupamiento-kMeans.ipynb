# %% [markdown]
# <a href="https://colab.research.google.com/github/andres-merino/Curso-FundMachineLearning/blob/main/3-Notebooks/05-2-Agrupamiento-kMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table style="border: none; border-collapse: collapse;">
#     <tr>
#         <td style="width: 20%; vertical-align: middle; padding-right: 10px;">
#             <img src="https://i0.wp.com/see-ec.org/wordpress/wp-content/uploads/2023/01/LOGO-SEE-texto-blanco-3.png?w=1356&ssl=1" width="200">
#         </td>
#         <td style="width: 2px; text-align: center;">
#             <font color="#008dc3" size="7">|</font><br>
#             <font color="#008dc3" size="7">|</font>
#         </td>
#         <td>
#             <p style="font-variant: small-caps;"><font color="#008dc3" size="5">
#                 <b>Sociedad Ecuatoriana de Estadística</b>
#             </font> </p>
#             <p style="font-variant: small-caps;"><font color="#008dc3" size="4">
#                 Fundamentos de Machine Learning &bull; Agrupamiento k-Means
#             </font></p>
#             <p style="font-style: oblique;"><font color="#008dc3" size="3">
#                 Andrés Merino &bull; Febrero 2026
#             </font></p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ---
# ## <font color='008dc3'> Introducción </font>
#
# Este notebook está diseñado como una guía introductoria para implementar el algoritmo de agrupamiento K-means en Python.

# %% [markdown]
# Los paquetes necesarios son:

# %%
import pandas as pd  # Manejo de datos
import numpy as np  # Operaciones matemáticas y arreglos
import matplotlib.pyplot as plt  # Visualización
import plotly.express as px # Para visualización interactiva

from sklearn.preprocessing import StandardScaler  # Estandarización de datos

from sklearn.datasets import make_blobs # Creación de datos de prueba
from sklearn.cluster import KMeans  # Algoritmo K-means
from sklearn.decomposition import PCA # Análisis de componentes principales

# %% [markdown]
# ---
# ## <font color='008dc3'> Ejemplo </font>
#
# En el siguiente código, se agrupan datos generados artificialmente en cuatro grupos utilizando el algoritmo K-means.  Se muestran los resultados mediante un gráfico de dispersión, destacando los centroides de los grupos.

# %%
# Generar datos de ejemplo
X, y_true = make_blobs(n_samples=300, centers=4, cluster_std=1.5, random_state=42)

# Visualizar los datos
plt.figure(figsize=(5, 4))
plt.scatter(X[:, 0], X[:, 1], s=50)
plt.title('Datos de ejemplo')
plt.show()

# %% [markdown]
# El código para generar el agrupamiento es el siguiente:

# %%
# Implementación de K-means
modelo = KMeans(n_clusters=4, random_state=42)
modelo.fit(X)
labels = modelo.labels_
print(labels)
# Out:
# [1 1 3 2 1 2 0 2 3 0 3 0 3 3 1 3 1 0 3 3 0 3 2 1 3 1 1 2 2 0 3 0 1 0 1 3 1
#  2 1 2 0 3 1 2 3 3 1 0 1 0 2 1 2 3 2 0 1 0 0 3 1 0 0 3 2 2 2 2 2 3 2 2 1 0
#  3 1 2 2 3 2 3 3 1 3 2 1 1 0 0 0 1 3 1 3 3 1 2 3 1 1 0 0 0 3 3 3 3 3 2 1 0
#  3 3 3 3 0 1 2 1 2 2 2 3 1 2 1 1 3 1 2 0 3 3 3 3 0 0 1 3 2 3 0 2 3 0 0 0 0
#  2 3 3 1 0 2 3 0 2 1 1 0 3 1 2 1 0 1 2 3 3 3 3 3 2 0 0 2 2 0 0 2 1 3 1 0 0
#  1 2 3 0 0 2 2 2 1 0 2 2 0 0 1 3 3 2 0 3 2 2 1 2 3 3 2 2 0 1 2 1 1 3 1 1 2
#  1 2 0 0 1 1 0 0 0 1 3 2 0 2 1 0 1 1 1 2 2 0 1 2 2 2 1 2 1 2 1 0 2 1 0 3 1
#  3 0 3 1 3 2 0 2 0 0 3 3 2 0 0 1 1 2 3 3 0 0 0 0 2 1 0 2 0 0 2 3 2 0 3 1 3
#  0 3 1 1]
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Revisemos el resultado de la ejecución del código:

# %%
# Visualizar los clusters
plt.figure(figsize=(5, 4))
plt.scatter(X[:, 0], X[:, 1], c=labels, s=50)
plt.title('Clusters')
plt.show()

# %% [markdown]
# Podemos obtener los centroides de los grupos con el siguiente código:

# %%
# Centroides
centroids = modelo.cluster_centers_
print(centroids)
# Out:
# [[ 4.75736792  2.07611029]
#  [-8.8911944   7.10011368]
#  [-6.80871448 -6.80563143]
#  [-2.76847921  8.96113041]]

# %% [markdown]
# Agreguemos los centroides al gráfico de dispersión:

# %%
# Gráfico con centroides
plt.figure(figsize=(5, 4))
plt.scatter(X[:, 0], X[:, 1], c=labels, s=50)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=200, marker='x')
plt.title('Clusters con centroides')
plt.show()

# %% [markdown]
# Podemos calcular la inercia de los grupos con el siguiente código:

# %%
# Inercia
modelo.inertia_
# Out:
# 1251.352629870747

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #008dc3; border-left: 5px solid #008dc3; padding: 0.5em;">
# <strong>Ejercicio:</strong><br>
# Utilizar k = 3 y comparar el resultado con k = 4.
# </div>
# </br>
#
# <div style="background-color: #edf1f8; border-color: #008dc3; border-left: 5px solid #008dc3; padding: 0.5em;">
# <strong>Ejercicio:</strong><br>
# Cambiar el método de inicialización a `'random'` y observar los efectos en la convergencia. Revisa la documentación de la función `KMeans` para obtener más información sobre este y otros parámetros.
# </div>

# %% [markdown]
# ### <font color='008dc3'> Método del codo </font>

# %% [markdown]
# Para seleccionar el número de clusters, se puede utilizar el método del codo. Este método consiste en graficar la suma de las distancias al cuadrado de cada punto al centroide más cercano en función del número de clusters. El punto en el que la pendiente de la curva disminuye drásticamente se considera el número óptimo de clusters.

# %%
# Metodo del codo
inertia = []
for i in range(1, 11):
    modelo = KMeans(n_clusters=i, random_state=42)
    modelo.fit(X)
    inertia.append(modelo.inertia_)
plt.figure(figsize=(5, 3))
plt.plot(range(1, 11), inertia, marker='o')
# Out:
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #008dc3; border-left: 5px solid #008dc3; padding: 0.5em;">
# <strong>Ejercicio:</strong><br>
# Realiza el agrupamiento con el número de clusters que consideres óptimo con la gráfica del método del codo.
# </div>

# %% [markdown]
# ---
# ## <font color='008dc3'> Ejemplo práctico </font>

# %% [markdown]
# ### <font color='008dc3'> Preprocesamiento de datos </font>

# %% [markdown]
# Primero leamos los datos y seleccionemos las columnas que utilizaremos:

# %%
# Leer los datos
data = pd.read_csv('https://raw.githubusercontent.com/andres-merino/Curso-FundMachineLearning/refs/heads/main/3-Notebooks/datos/Pokemon.csv')
# Tomo las columnas de interés
numeric_cols = ['Attack', 'Defense', 'Speed', 'Sp. Atk', 'Sp. Def', 'HP']
data = data[['Name', *numeric_cols]]
# Muestro los primeros registros
display(data.head())
# Out:
#          Name  Attack  Defense  Speed  Sp. Atk  Sp. Def  HP
# 0   Bulbasaur      49       49     45       65       65  45
# 1     Ivysaur      62       63     60       80       80  60
# 2    Venusaur      82       83     80      100      100  80
# 3  Charmander      52       43     65       60       50  39
# 4  Charmeleon      64       58     80       80       65  58

# %% [markdown]
# Revisemos los datos:

# %%
data.describe()
# Out:
#            Attack     Defense       Speed     Sp. Atk     Sp. Def          HP
# count  151.000000  151.000000  151.000000  151.000000  151.000000  151.000000
# mean    72.549669   68.225166   68.933775   67.139073   66.019868   64.211921
# std     26.596162   26.916704   26.746880   28.534199   24.197926   28.590117
# min      5.000000    5.000000   15.000000   15.000000   20.000000   10.000000
# 25%     51.000000   50.000000   46.500000   45.000000   49.000000   45.000000
# 50%     70.000000   65.000000   70.000000   65.000000   65.000000   60.000000
# 75%     90.000000   84.000000   90.000000   87.500000   80.000000   80.000000
# max    134.000000  180.000000  140.000000  154.000000  125.000000  250.000000

# %% [markdown]
# Escalemos los datos:

# %%
# Escalar los datos
scaler = StandardScaler()
X = scaler.fit_transform(data.iloc[:, 1:])

# %% [markdown]
# ### <font color='008dc3'> Determinación del número de clusters </font>

# %% [markdown]
# Realicemos el método del codo para determinar el número de clusters óptimo:

# %%
# Metodo del codo
inertia = []
for i in range(1, 11):
    modelo = KMeans(n_clusters=i, random_state=42)
    modelo.fit(X)
    inertia.append(modelo.inertia_)
plt.figure(figsize=(5, 3))
plt.plot(range(1, 11), inertia, marker='o')
# Out:
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# El número óptimo de clusters parece ser 4 o 6. Utilicemos 6 clusters para el agrupamiento.

# %% [markdown]
# ### <font color='008dc3'> k-Means </font>

# %% [markdown]
# Generamos el agrupamiento:

# %%
# Realizamos el agrupamiento
modelo = KMeans(n_clusters=6, random_state=42)
modelo.fit(X)

# Asignamos las etiquetas
labels = modelo.labels_

# Agregar la información de clúster como C1, C2, C3, etc.
data['Cluster'] = ['C' + str(c) for c in labels]

# Revisar los primeros registros
display(data.head())
# Out:
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#          Name  Attack  Defense  Speed  Sp. Atk  Sp. Def  HP Cluster
# 0   Bulbasaur      49       49     45       65       65  45      C5
# 1     Ivysaur      62       63     60       80       80  60      C5
# 2    Venusaur      82       83     80      100      100  80      C2
# 3  Charmander      52       43     65       60       50  39      C4
# 4  Charmeleon      64       58     80       80       65  58      C3

# %% [markdown]
# ### <font color='008dc3'> Análisis de clústers </font>

# %% [markdown]
# Revisemos la cantidad de cada cluster:

# %%
# Cantidades de elementos por clúster
data['Cluster'].value_counts()
# Out:
# Cluster
# C3    38
# C5    35
# C2    31
# C4    25
# C1    21
# C0     1
# Name: count, dtype: int64

# %% [markdown]
# Podemos analizar las características de cada cluster:

# %%
# Podemos ver las medias de cada clúster
data.groupby('Cluster')[numeric_cols].mean()
# Out:
#             Attack     Defense      Speed    Sp. Atk     Sp. Def          HP
# Cluster
# C0        5.000000    5.000000  50.000000  35.000000  105.000000  250.000000
# C1       91.904762  108.809524  50.952381  51.666667   50.000000   57.619048
# C2       93.548387   82.000000  71.612903  91.354839   89.838710   94.903226
# C3       78.473684   64.105263  99.184211  79.631579   78.684211   61.526316
# C4       45.720000   41.280000  68.640000  43.440000   39.600000   36.320000
# C5       57.000000   57.200000  45.257143  59.257143   58.542857   58.514286

# %% [markdown]
# Revisemos los cinco primeros elementos de cada cluster:

# %%
# Mostremos los nombres de 5 pokemones de cada clúster
for cluster in data['Cluster'].unique():
    print(f'Cluster {cluster}: cantidad de elementos {data[data["Cluster"] == cluster].shape[0]}')
    display(data[data['Cluster'] == cluster].head(5))
# Out:
# Cluster C5: cantidad de elementos 35
#           Name  Attack  Defense  Speed  Sp. Atk  Sp. Def  HP Cluster
# 0    Bulbasaur      49       49     45       65       65  45      C5
# 1      Ivysaur      62       63     60       80       80  60      C5
# 6     Squirtle      48       65     43       50       64  44      C5
# 7    Wartortle      63       80     58       65       80  59      C5
# 11  Butterfree      45       50     70       90       80  60      C5
# Cluster C2: cantidad de elementos 31
#          Name  Attack  Defense  Speed  Sp. Atk  Sp. Def  HP Cluster
# 2    Venusaur      82       83     80      100      100  80      C2
# 8   Blastoise      83      100     78       85      105  79      C2
# 30  Nidoqueen      92       87     76       75       85  90      C2
# 33   Nidoking     102       77     85       85       75  81      C2
# 35   Clefable      70       73     60       95       90  95      C2
# Cluster C4: cantidad de elementos 25
#           Name  Attack  Defense  Speed  Sp. Atk  Sp. Def  HP Cluster
# 3   Charmander      52       43     65       60       50  39      C4
# 9     Caterpie      30       35     45       20       20  45      C4
# 10     Metapod      20       55     30       25       25  50      C4
# 12      Weedle      35       30     50       20       20  40      C4
# 13      Kakuna      25       50     35       25       25  45      C4
# Cluster C3: cantidad de elementos 38
#           Name  Attack  Defense  Speed  Sp. Atk  Sp. Def  HP Cluster
# 4   Charmeleon      64       58     80       80       65  58      C3
# 5    Charizard      84       78    100      109       85  78      C3
# 14    Beedrill      90       40     75       45       80  65      C3
# 17     Pidgeot      80       75    101       70       70  83      C3
# 19    Raticate      81       60     97       50       70  55      C3
# Cluster C1: cantidad de elementos 21
#          Name  Attack  Defense  Speed  Sp. Atk  Sp. Def  HP Cluster
# 26  Sandshrew      75       85     40       20       30  50      C1
# 27  Sandslash     100      110     65       45       55  75      C1
# 46   Parasect      95       80     30       60       80  60      C1
# 66    Machoke     100       70     45       50       60  80      C1
# 73    Geodude      80      100     20       30       30  40      C1
# Cluster C0: cantidad de elementos 1
#         Name  Attack  Defense  Speed  Sp. Atk  Sp. Def   HP Cluster
# 112  Chansey       5        5     50       35      105  250      C0

# %% [markdown]
# ### <font color='008dc3'> Visualizaciones  </font>

# %%
# Realizo un PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Crear un DataFrame para graficar fácilmente
df_pca = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
df_pca['Name'] = data['Name'].values
df_pca['Cluster'] = data['Cluster'].values

# Crear el scatterplot interactivo con Plotly Express
fig = px.scatter(
    df_pca, 
    x='PC1', 
    y='PC2', 
    color='Cluster',
    hover_data=['Name'],  # Mostrará 'Name'
)

# Personalizar apariencia
fig.update_traces(marker=dict(opacity=0.8))
fig.update_layout(
    title='Clústeres visualizados en 2D (PCA)',
    width=800,
    height=600,
)

fig.show()
# Out:
# c:\Users\aemer\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\express\_core.py:1979: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   sf: grouped.get_group(s if len(s) > 1 else s[0])

# %% [markdown]
# <div style="background-color: #edf1f8; border-color: #008dc3; border-left: 5px solid #008dc3; padding: 0.5em;">
# <strong>Ejercicio:</strong><br>
# Genera el agrupamiento con otro número de clusters que consideraste óptimo.
# </div>
