# %% [markdown]
# <a href="https://colab.research.google.com/github/andres-merino/Curso-FundMachineLearning/blob/main/3-Notebooks/08-5-Perceptron-Practica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table style="border: none; border-collapse: collapse;">
#     <tr>
#         <td style="width: 20%; vertical-align: middle; padding-right: 10px;">
#             <img src="https://i0.wp.com/see-ec.org/wordpress/wp-content/uploads/2023/01/LOGO-SEE-texto-blanco-3.png?w=1356&ssl=1" width="200">
#         </td>
#         <td style="width: 2px; text-align: center;">
#             <font color="#008dc3" size="7">|</font><br>
#             <font color="#008dc3" size="7">|</font>
#         </td>
#         <td>
#             <p style="font-variant: small-caps;"><font color="#008dc3" size="5">
#                 <b>Sociedad Ecuatoriana de Estadística</b>
#             </font> </p>
#             <p style="font-variant: small-caps;"><font color="#008dc3" size="4">
#                 Fundamentos de Machine Learning &bull; Perceptrón: práctica
#             </font></p>
#             <p style="font-style: oblique;"><font color="#008dc3" size="3">
#                 Andrés Merino &bull; Febrero 2026
#             </font></p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ---
# ## <font color='008dc3'> Introducción </font>
#
# Este notebook está diseñado como una guía introductoria para implementar un perceptrón en un caso práctico.

# %% [markdown]
# Los paquetes necesarios son:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.utils import to_categorical

# %%
# Fijar las semillas para reproducibilidad
import random
import os
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    tf.config.experimental.enable_op_determinism()
    os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
    os.environ["TF_DETERMINISTIC_OPS"] = "1"

# %% [markdown]
# ---
# ## <font color='008dc3'> Ejemplo práctico </font>

# %% [markdown]
# ### <font color='008dc3'> Preprocesamiento de datos </font>

# %% [markdown]
# Primero leamos los datos y seleccionemos las columnas que utilizaremos:

# %%
# Leer los datos
data = pd.read_csv('https://raw.githubusercontent.com/andres-merino/Curso-FundMachineLearning/refs/heads/main/3-Notebooks/datos/Pokemon.csv')
# Tomo las columnas de interés
numeric_cols = ['Attack', 'Defense', 'Speed', 'Sp. Atk', 'Sp. Def', 'HP']
class_col = ['Stage']
data = data[['Name', *numeric_cols, *class_col]]
# Muestro los primeros registros
display(data.head())
# Out:
#          Name  Attack  Defense  Speed  Sp. Atk  Sp. Def  HP  Stage
# 0   Bulbasaur      49       49     45       65       65  45      2
# 1     Ivysaur      62       63     60       80       80  60      1
# 2    Venusaur      82       83     80      100      100  80      0
# 3  Charmander      52       43     65       60       50  39      2
# 4  Charmeleon      64       58     80       80       65  58      1

# %% [markdown]
# Revisemos los datos:

# %%
data.describe()
# Out:
#            Attack     Defense       Speed     Sp. Atk     Sp. Def          HP  \
# count  151.000000  151.000000  151.000000  151.000000  151.000000  151.000000
# mean    72.549669   68.225166   68.933775   67.139073   66.019868   64.211921
# std     26.596162   26.916704   26.746880   28.534199   24.197926   28.590117
# min      5.000000    5.000000   15.000000   15.000000   20.000000   10.000000
# 25%     51.000000   50.000000   46.500000   45.000000   49.000000   45.000000
# 50%     70.000000   65.000000   70.000000   65.000000   65.000000   60.000000
# 75%     90.000000   84.000000   90.000000   87.500000   80.000000   80.000000
# max    134.000000  180.000000  140.000000  154.000000  125.000000  250.000000
#
#             Stage
# count  151.000000
# mean     0.569536
# std      0.678331
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      2.000000

# %% [markdown]
# Escalemos los datos:

# %%
# Escalar los datos
scaler = StandardScaler()
X = scaler.fit_transform(data.iloc[:, 1:-1])
# Codificar las clases
y_one_hot = to_categorical(data['Stage'])

# %% [markdown]
# Dividimos los datos en entrenamiento y prueba:

# %%
# Dividir los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=0.2, random_state=42, stratify=data['Stage'])

# %% [markdown]
# ### <font color='008dc3'> Modelado y entrenamiento </font>

# %% [markdown]
# Definimos la red:

# %%
# Creamos el modelo
set_seed(42)
model = Sequential([
    Input(shape=(6,)),
    Dense(12, activation='tanh'),
    Dense(6, activation='tanh'),
    Dense(3, activation='softmax')
])
# Compilamos el modelo
optimizer = SGD(learning_rate=0.1)
loss = CategoricalCrossentropy()
model.compile(optimizer=optimizer, loss=loss)
# Resumen del modelo
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 12)                84
#
#  dense_7 (Dense)             (None, 6)                 78
#
#  dense_8 (Dense)             (None, 3)                 21
#
# =================================================================
# Total params: 183
# Trainable params: 183
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Realizamos el entrenamiento:

# %%
# Entrenar el modelo
history = model.fit(X_train, y_train, epochs=100, verbose=1)

# Visualizar la pérdida
plt.plot(history.history['loss'])
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1666
# Epoch 2/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.8591
# Epoch 3/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7078
# Epoch 4/100
# 4/4 [==============================] - 0s 1000us/step - loss: 0.6257
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5782
# Epoch 6/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5461
# Epoch 7/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5235
# Epoch 8/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5086
# Epoch 9/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4942
# Epoch 10/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4836
# Epoch 11/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4751
# Epoch 12/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4681
# Epoch 13/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.4645
# Epoch 14/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.4561
# Epoch 15/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.4514
# Epoch 16/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.4486
# Epoch 17/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.4435
# Epoch 18/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.4387
# Epoch 19/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4364
# Epoch 20/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.4314
# Epoch 21/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4270
# Epoch 22/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4251
# Epoch 23/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4213
# Epoch 24/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.4195
# Epoch 25/100
# 4/4 [==============================] - 0s 999us/step - loss: 0.4147
# Epoch 26/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.4136
# Epoch 27/100
# 4/4 [==============================] - 0s 999us/step - loss: 0.4102
# Epoch 28/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.4049
# Epoch 29/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.4046
# Epoch 30/100
# 4/4 [==============================] - 0s 1000us/step - loss: 0.4021
# Epoch 31/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4017
# Epoch 32/100
# 4/4 [==============================] - 0s 1000us/step - loss: 0.3962
# Epoch 33/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3937
# Epoch 34/100
# 4/4 [==============================] - 0s 999us/step - loss: 0.3937
# Epoch 35/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.3877
# Epoch 36/100
# 4/4 [==============================] - 0s 1000us/step - loss: 0.3872
# Epoch 37/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3850
# Epoch 38/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.3837
# Epoch 39/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3800
# Epoch 40/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3815
# Epoch 41/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3763
# Epoch 42/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3759
# Epoch 43/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3709
# Epoch 44/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.3714
# Epoch 45/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3664
# Epoch 46/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3647
# Epoch 47/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3635
# Epoch 48/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3617
# Epoch 49/100
# 4/4 [==============================] - 0s 1000us/step - loss: 0.3600
# Epoch 50/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3571
# Epoch 51/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3544
# Epoch 52/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3530
# Epoch 53/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3508
# Epoch 54/100
# 4/4 [==============================] - 0s 999us/step - loss: 0.3496
# Epoch 55/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3468
# Epoch 56/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3441
# Epoch 57/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3421
# Epoch 58/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3402
# Epoch 59/100
# 4/4 [==============================] - 0s 835us/step - loss: 0.3411
# Epoch 60/100
# 4/4 [==============================] - 0s 999us/step - loss: 0.3375
# Epoch 61/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3354
# Epoch 62/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3334
# Epoch 63/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3399
# Epoch 64/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3312
# Epoch 65/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.3304
# Epoch 66/100
# 4/4 [==============================] - 0s 999us/step - loss: 0.3265
# Epoch 67/100
# 4/4 [==============================] - 0s 1000us/step - loss: 0.3242
# Epoch 68/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3238
# Epoch 69/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3229
# Epoch 70/100
# 4/4 [==============================] - 0s 1000us/step - loss: 0.3196
# Epoch 71/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3193
# Epoch 72/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3202
# Epoch 73/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.3249
# Epoch 74/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.3168
# Epoch 75/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3139
# Epoch 76/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.3140
# Epoch 77/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3120
# Epoch 78/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3100
# Epoch 79/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.3123
# Epoch 80/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3066
# Epoch 81/100
# 4/4 [==============================] - 0s 835us/step - loss: 0.3062
# Epoch 82/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3050
# Epoch 83/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.3058
# Epoch 84/100
# 4/4 [==============================] - 0s 837us/step - loss: 0.3120
# Epoch 85/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.3047
# Epoch 86/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3036
# Epoch 87/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.3004
# Epoch 88/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2995
# Epoch 89/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.2990
# Epoch 90/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.2974
# Epoch 91/100
# 4/4 [==============================] - 0s 998us/step - loss: 0.2994
# Epoch 92/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.2985
# Epoch 93/100
# 4/4 [==============================] - 0s 1000us/step - loss: 0.2931
# Epoch 94/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2953
# Epoch 95/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.2919
# Epoch 96/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.2966
# Epoch 97/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.2891
# Epoch 98/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.2895
# Epoch 99/100
# 4/4 [==============================] - 0s 833us/step - loss: 0.2935
# Epoch 100/100
# 4/4 [==============================] - 0s 834us/step - loss: 0.2892

# %% [markdown]
# ### <font color='008dc3'> Evaluación </font>

# %%
# Realizar predicciones y evaluar el modelo
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_test = np.argmax(y_test, axis=1)

# Precisión del modelo con dos decimales
accuracy = round(accuracy_score(y_test, y_pred), 2)
print("Precisión del modelo:", accuracy)

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)
print("Matriz de confusión:")
print(cm)

# Reporte de clasificación
print("Reporte de clasificación:")
print(classification_report(y_test, y_pred))
# Out:
# 1/1 [==============================] - 0s 42ms/step
# Precisión del modelo: 0.84
# Matriz de confusión:
# [[16  1  0]
#  [ 2  9  0]
#  [ 0  2  1]]
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91        17
#            1       0.75      0.82      0.78        11
#            2       1.00      0.33      0.50         3
#
#     accuracy                           0.84        31
#    macro avg       0.88      0.70      0.73        31
# weighted avg       0.85      0.84      0.83        31
