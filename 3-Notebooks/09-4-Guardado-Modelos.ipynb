# %% [markdown]
# <a href="https://colab.research.google.com/github/andres-merino/Curso-FundMachineLearning/blob/main/3-Notebooks/09-4-Guardado-Modelos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table style="border: none; border-collapse: collapse;">
#     <tr>
#         <td style="width: 20%; vertical-align: middle; padding-right: 10px;">
#             <img src="https://i0.wp.com/see-ec.org/wordpress/wp-content/uploads/2023/01/LOGO-SEE-texto-blanco-3.png?w=1356&ssl=1" width="200">
#         </td>
#         <td style="width: 2px; text-align: center;">
#             <font color="#008dc3" size="7">|</font><br>
#             <font color="#008dc3" size="7">|</font>
#         </td>
#         <td>
#             <p style="font-variant: small-caps;"><font color="#008dc3" size="5">
#                 <b>Sociedad Ecuatoriana de Estadística</b>
#             </font> </p>
#             <p style="font-variant: small-caps;"><font color="#008dc3" size="4">
#                 Fundamentos de Machine Learning &bull; Guardado de Modelos
#             </font></p>
#             <p style="font-style: oblique;"><font color="#008dc3" size="3">
#                 Andrés Merino &bull; Febrero 2026
#             </font></p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ---
# ## <font color='008dc3'> Introducción </font>
#
# Este notebook está diseñado como una guía introductoria para implementar el guardado de modelos de aprendizaje automático en Python.

# %% [markdown]
# Los paquetes necesarios son:

# %%
import pandas as pd  # Manejo de datos

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier

import joblib
import pickle

# %% [markdown]
# ### <font color='008dc3'> Preprocesamiento de datos </font>

# %% [markdown]
# Primero leamos los datos y seleccionemos las columnas que utilizaremos:

# %%
# Leer los datos
data = pd.read_csv('https://raw.githubusercontent.com/andres-merino/Curso-FundMachineLearning/refs/heads/main/3-Notebooks/datos/Pokemon.csv')
# Tomo las columnas de interés
numeric_cols = ['Attack', 'Defense', 'Speed', 'Sp. Atk', 'Sp. Def', 'HP']
class_col = ['Stage']
data = data[['Name', *numeric_cols, *class_col]]
# Muestro los primeros registros
display(data.head())
# Out:
#          Name  Attack  Defense  Speed  Sp. Atk  Sp. Def  HP  Stage
# 0   Bulbasaur      49       49     45       65       65  45      2
# 1     Ivysaur      62       63     60       80       80  60      1
# 2    Venusaur      82       83     80      100      100  80      0
# 3  Charmander      52       43     65       60       50  39      2
# 4  Charmeleon      64       58     80       80       65  58      1

# %%
X = data[numeric_cols]
y = data['Stage']

# %% [markdown]
# ---
# ## <font color='008dc3'> Guardado de modelos </font>

# %% [markdown]
# ### <font color='008dc3'> Modelo </font>

# %% [markdown]
# Definimos el modelo:

# %%
# Crear y entrenar un arbol con ganancia de información
modelo = RandomForestClassifier(random_state=42, n_estimators=50, max_depth=15)
modelo.fit(X, y)
# Out:
# RandomForestClassifier(max_depth=15, n_estimators=50, random_state=42)

# %% [markdown]
# Revisamos precisión en entrenamiento:

# %%
# Realizar predicciones y evaluar el modelo
y_pred = modelo.predict(X)

# Precisión del modelo con dos decimales
accuracy = round(accuracy_score(y, y_pred), 2)
print("Precisión del modelo:", accuracy)

# Matriz de confusión
cm = confusion_matrix(y, y_pred)
print("Matriz de confusión:")
print(cm)

# Reporte de clasificación
print("Reporte de clasificación:")
print(classification_report(y, y_pred))
# Out:
# Precisión del modelo: 1.0
# Matriz de confusión:
# [[81  0  0]
#  [ 0 54  0]
#  [ 0  0 16]]
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        81
#            1       1.00      1.00      1.00        54
#            2       1.00      1.00      1.00        16
#
#     accuracy                           1.00       151
#    macro avg       1.00      1.00      1.00       151
# weighted avg       1.00      1.00      1.00       151

# %% [markdown]
# Guardamos el modelo:

# %%
# Guardar el modelo
with open('modelo_pokemon.pkl', 'wb') as file:
    pickle.dump(modelo, file)

with open('modelo_pokemon.joblib', 'wb') as file:
    joblib.dump(modelo, file)
